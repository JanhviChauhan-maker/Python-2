# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("auto-mpg.csv")

# %%
df
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model year  origin                   car name
# 0            70       1  chevrolet chevelle malibu
# ...

# %%
df=df[df["horsepower"]!="?"]
df
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model year  origin                   car name
# 0            70       1  chevrolet chevelle malibu
# ...

# %%
df["horsepower"]=df["horsepower"].astype("int")
# Out:
# <ipython-input-6-e59d546c0ee2>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["horsepower"]=df["horsepower"].astype("int")

# %%
df.dtypes
# Out:
# mpg             float64
# cylinders         int64
# displacement    float64
# horsepower        int32
# weight            int64
# acceleration    float64
# model year        int64
# origin            int64
# car name         object
# dtype: object

# %%
df.describe(include="object")
# Out:
#           car name
# count          392
# unique         301
# top     ford pinto
# freq             5

# %%
df.corr() #correalation
# Out:
#                    mpg  cylinders  displacement  horsepower    weight  \
# mpg           1.000000  -0.777618     -0.805127   -0.778427 -0.832244
# cylinders    -0.777618   1.000000      0.950823    0.842983  0.897527
# displacement -0.805127   0.950823      1.000000    0.897257  0.932994
# horsepower   -0.778427   0.842983      0.897257    1.000000  0.864538
# weight       -0.832244   0.897527      0.932994    0.864538  1.000000
# acceleration  0.423329  -0.504683     -0.543800   -0.689196 -0.416839
# model year    0.580541  -0.345647     -0.369855   -0.416361 -0.309120
# origin        0.565209  -0.568932     -0.614535   -0.455171 -0.585005
#
#               acceleration  model year    origin
# mpg               0.423329    0.580541  0.565209
# cylinders        -0.504683   -0.345647 -0.568932
# displacement     -0.543800   -0.369855 -0.614535
# horsepower       -0.689196   -0.416361 -0.455171
# weight           -0.416839   -0.309120 -0.585005
# ...

# %%
import seaborn as sns

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(df.corr(),annot=True,vmin=0)
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(df.corr(),annot=True,vmax=0.5)
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(df.corr(),annot=True,linewidth=5,linecolor="black",cbar=False,cmap="coolwarm")
# Out:
# <AxesSubplot:>

# %%
sns.scatterplot(data=df,x="horsepower",y="weight",style="cylinders",s=100)
# Out:
# <AxesSubplot:xlabel='horsepower', ylabel='weight'>

# %%
import plotly.express as px

# %%
ds=pd.read_csv("social_media_engagement.csv")

# %%
ds.head()
# Out:
#    post_id   platform post_type        post_time  likes  comments  shares  \
# 0        1   Facebook     image  8/17/2023 14:45   2121       474     628
# 1        2   Facebook  carousel   5/14/2023 0:45   3660       432     694
# 2        3  Instagram      poll  2/21/2023 16:15   4955       408     688
# 3        4    Twitter     image  11/16/2023 0:45   1183        90     187
# 4        5    Twitter     video   5/23/2023 0:30   3499       247     286
#
#    post_day sentiment_score
# 0  Thursday        positive
# 1    Sunday         neutral
# 2   Tuesday        negative
# 3  Thursday        negative
# 4   Tuesday        positive

# %%
ds.isna().sum()
# Out:
# post_id            0
# platform           0
# post_type          0
# post_time          0
# likes              0
# comments           0
# shares             0
# post_day           0
# sentiment_score    0
# dtype: int64

# %%
ds
# Out:
#     post_id   platform post_type         post_time  likes  comments  shares  \
# 0         1   Facebook     image   8/17/2023 14:45   2121       474     628
# 1         2   Facebook  carousel    5/14/2023 0:45   3660       432     694
# 2         3  Instagram      poll   2/21/2023 16:15   4955       408     688
# 3         4    Twitter     image   11/16/2023 0:45   1183        90     187
# 4         5    Twitter     video    5/23/2023 0:30   3499       247     286
# ..      ...        ...       ...               ...    ...       ...     ...
# 95       96  Instagram  carousel   7/12/2023 17:45     36       294     911
# 96       97    Twitter     video  10/27/2023 23:45    314       108     458
# 97       98    Twitter      text     8/5/2023 8:45    229       179      38
# 98       99  Instagram      poll  12/29/2023 12:15   5000       500     204
# 99      100  Instagram     image    6/6/2023 21:00   4483       357      25
#
#      post_day sentiment_score
# ...

# %%
ds.nunique()
# Out:
# post_id            100
# platform             3
# post_type            5
# post_time           99
# likes               93
# comments            85
# shares              96
# post_day             7
# sentiment_score      3
# dtype: int64

# %%
ds.platform.unique()
# Out:
# array(['Facebook', 'Instagram', 'Twitter'], dtype=object)

# %%
ds.sentiment_score
# Out:
# 0     positive
# 1      neutral
# 2     negative
# 3     negative
# 4     positive
#         ...
# 95    positive
# 96     neutral
# 97    positive
# 98    positive
# 99     neutral
# Name: sentiment_score, Length: 100, dtype: object

# %%
ds
# Out:
#     post_id   platform post_type         post_time  likes  comments  shares  \
# 0         1   Facebook     image   8/17/2023 14:45   2121       474     628
# 1         2   Facebook  carousel    5/14/2023 0:45   3660       432     694
# 2         3  Instagram      poll   2/21/2023 16:15   4955       408     688
# 3         4    Twitter     image   11/16/2023 0:45   1183        90     187
# 4         5    Twitter     video    5/23/2023 0:30   3499       247     286
# ..      ...        ...       ...               ...    ...       ...     ...
# 95       96  Instagram  carousel   7/12/2023 17:45     36       294     911
# 96       97    Twitter     video  10/27/2023 23:45    314       108     458
# 97       98    Twitter      text     8/5/2023 8:45    229       179      38
# 98       99  Instagram      poll  12/29/2023 12:15   5000       500     204
# 99      100  Instagram     image    6/6/2023 21:00   4483       357      25
#
#      post_day sentiment_score
# ...

# %%
v=ds[ds["platform"]=="Facebook"]
v
# Out:
#     post_id  platform post_type         post_time  likes  comments  shares  \
# 0         1  Facebook     image   8/17/2023 14:45   2121       474     628
# 1         2  Facebook  carousel    5/14/2023 0:45   3660       432     694
# 8         9  Facebook     video     5/2/2023 6:15    317       249     221
# 12       13  Facebook  carousel  11/11/2023 15:45     45        78     375
# 14       15  Facebook  carousel    1/9/2023 20:00    889       314     262
# 19       20  Facebook     image    2/2/2023 16:00    455        86      79
# 25       26  Facebook  carousel    10/5/2023 6:30   1992        70     515
# 27       28  Facebook      poll     3/1/2023 8:00   2083       500     388
# 28       29  Facebook     image    1/7/2023 10:30    548       153     731
# 29       30  Facebook  carousel     2/3/2023 0:30   4594       216     739
# 30       31  Facebook      poll   9/10/2023 13:45   4795       449     978
# ...

# %%
v["likes"].sum()
# Out:
# 86392

# %%
ds.groupby("platform")["likes"].sum()
# Out:
# platform
# Facebook      86392
# Instagram    107994
# Twitter       43795
# Name: likes, dtype: int64

# %%
ds.groupby("platform")["comments","likes","shares"].mean()
# Out:
# <ipython-input-76-1a6007219ff6>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   ds.groupby("platform")["comments","likes","shares"].mean()
#              comments        likes      shares
# platform
# Facebook   248.906250  2699.750000  474.375000
# Instagram  232.444444  2999.833333  525.166667
# Twitter    122.906250  1368.593750  233.718750

# %%
ds.groupby("platform")["comments","likes","shares"].sum()
# Out:
# <ipython-input-77-df7ceddf60c6>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   ds.groupby("platform")["comments","likes","shares"].sum()
#            comments   likes  shares
# platform
# Facebook       7965   86392   15180
# Instagram      8368  107994   18906
# Twitter        3933   43795    7479

# %%
ds['category']=ds['likes'].apply(lambda x: ' good' if x<50000 else '  very good')

# %%
ds
# Out:
#     post_id   platform post_type         post_time  likes  comments  shares  \
# 0         1   Facebook     image   8/17/2023 14:45   2121       474     628
# 1         2   Facebook  carousel    5/14/2023 0:45   3660       432     694
# 2         3  Instagram      poll   2/21/2023 16:15   4955       408     688
# 3         4    Twitter     image   11/16/2023 0:45   1183        90     187
# 4         5    Twitter     video    5/23/2023 0:30   3499       247     286
# ..      ...        ...       ...               ...    ...       ...     ...
# 95       96  Instagram  carousel   7/12/2023 17:45     36       294     911
# 96       97    Twitter     video  10/27/2023 23:45    314       108     458
# 97       98    Twitter      text     8/5/2023 8:45    229       179      38
# 98       99  Instagram      poll  12/29/2023 12:15   5000       500     204
# 99      100  Instagram     image    6/6/2023 21:00   4483       357      25
#
#      post_day sentiment_score   category
# ...

# %%
x=ds.groupby("platform")['likes'].sum().apply(lambda x: ' good' if x<50000 else '  very good')

# %%
x
# Out:
# platform
# Facebook       very good
# Instagram      very good
# Twitter             good
# Name: likes, dtype: object

# %%
ds.groupby("platform",sort=True).sample()
# Out:
#     post_id   platform post_type         post_time  likes  comments  shares  \
# 46       47   Facebook      poll    8/8/2023 17:45   4726        44     993
# 60       61  Instagram     video  12/31/2023 22:30   3544       167     761
# 42       43    Twitter  carousel   3/31/2023 16:00   2586        97      85
#
#    post_day sentiment_score category
# 46  Tuesday        negative     good
# 60   Sunday        negative     good
# 42   Friday        positive     good

# %%
ds.groupby("platform",sort=True).head()
# Out:
#     post_id   platform post_type         post_time  likes  comments  shares  \
# 0         1   Facebook     image   8/17/2023 14:45   2121       474     628
# 1         2   Facebook  carousel    5/14/2023 0:45   3660       432     694
# 2         3  Instagram      poll   2/21/2023 16:15   4955       408     688
# 3         4    Twitter     image   11/16/2023 0:45   1183        90     187
# 4         5    Twitter     video    5/23/2023 0:30   3499       247     286
# 5         6  Instagram  carousel    5/5/2023 20:00    256       186     211
# 6         7  Instagram     image   2/26/2023 11:45   1982        30     906
# 7         8  Instagram      text  10/28/2023 19:30   1274        45     216
# 8         9   Facebook     video     5/2/2023 6:15    317       249     221
# 9        10    Twitter  carousel   5/11/2023 11:00   1878       225     438
# 10       11    Twitter      text    12/8/2023 2:15   1446        44      52
# ...

# %%
ds.groupby("platform",sort=True).describe()
# Out:
#           post_id                                                       likes  \
#             count       mean        std  min    25%   50%    75%    max count
# platform
# Facebook     32.0  51.531250  29.195652  1.0  28.75  53.0  76.25   94.0  32.0
# Instagram    36.0  57.472222  28.866675  3.0  38.75  60.5  79.75  100.0  36.0
# Twitter      32.0  41.625000  27.492814  4.0  18.75  39.5  56.00   98.0  32.0
#
#                         ... comments        shares                          \
#                   mean  ...      75%    max  count        mean         std
# platform                ...
# Facebook   2699.750000  ...   393.00  500.0   32.0  474.375000  299.739430
# Instagram  2999.833333  ...   339.00  500.0   36.0  525.166667  284.467472
# Twitter    1368.593750  ...   162.25  247.0   32.0  233.718750  156.508525
#
#
#             min     25%    50%     75%    max
# platform
# Facebook   16.0  283.00  408.5  728.75  993.0
# Instagram  25.0  226.50  573.5  758.00  956.0
# ...

# %%
ds.groupby("platform").size()
# Out:
# platform
# Facebook     32
# Instagram    36
# Twitter      32
# dtype: int64

# %%
ds.shape
# Out:
# (100, 10)

# %%
ds.groupby("platform").groups
# Out:
# {'Facebook': [0, 1, 8, 12, 14, 19, 25, 27, 28, 29, 30, 35, 36, 38, 46, 47, 57, 61, 65, 66, 69, 71, 72, 74, 79, 80, 83, 84, 87, 90, 91, 93], 'Instagram': [2, 5, 6, 7, 16, 23, 26, 31, 34, 39, 41, 43, 45, 49, 53, 55, 56, 59, 60, 63, 64, 67, 70, 73, 75, 77, 78, 81, 82, 86, 89, 92, 94, 95, 98, 99], 'Twitter': [3, 4, 9, 10, 11, 13, 15, 17, 18, 20, 21, 22, 24, 32, 33, 37, 40, 42, 44, 48, 50, 51, 52, 54, 58, 62, 68, 76, 85, 88, 96, 97]}

# %%
for i,j in ds.groupby("platform"):
    print(i,"name")
    print(j,"data")
# Out:
# Facebook name
#     post_id  platform post_type         post_time  likes  comments  shares  \
# 0         1  Facebook     image   8/17/2023 14:45   2121       474     628
# 1         2  Facebook  carousel    5/14/2023 0:45   3660       432     694
# 8         9  Facebook     video     5/2/2023 6:15    317       249     221
# 12       13  Facebook  carousel  11/11/2023 15:45     45        78     375
# 14       15  Facebook  carousel    1/9/2023 20:00    889       314     262
# 19       20  Facebook     image    2/2/2023 16:00    455        86      79
# 25       26  Facebook  carousel    10/5/2023 6:30   1992        70     515
# 27       28  Facebook      poll     3/1/2023 8:00   2083       500     388
# 28       29  Facebook     image    1/7/2023 10:30    548       153     731
# 29       30  Facebook  carousel     2/3/2023 0:30   4594       216     739
# 30       31  Facebook      poll   9/10/2023 13:45   4795       449     978
# ...

# %%
ds.groupby("platform").nth(0)
# Out:
#            post_id post_type        post_time  likes  comments  shares  \
# platform
# Facebook         1     image  8/17/2023 14:45   2121       474     628
# Instagram        3      poll  2/21/2023 16:15   4955       408     688
# Twitter          4     image  11/16/2023 0:45   1183        90     187
#
#            post_day sentiment_score category
# platform
# Facebook   Thursday        positive     good
# Instagram   Tuesday        negative     good
# Twitter    Thursday        negative     good

# %%
ds.groupby("platform").nunique()
# Out:
#            post_id  post_type  post_time  likes  comments  shares  post_day  \
# platform
# Facebook        32          5         32     29        28      32         7
# Instagram       36          5         36     33        34      36         7
# Twitter         32          5         32     32        31      31         7
#
#            sentiment_score  category
# platform
# Facebook                 3         1
# Instagram                3         1
# Twitter                  3         1

# %%
ds.groupby("platform").agg({"likes":sum,"comments":max})
# Out:
#             likes  comments
# platform
# Facebook    86392       500
# Instagram  107994       500
# Twitter     43795       247

# %%
ds=pd.read_csv("ipl-matches.csv")

# %%
ds
# Out:
#           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  2022-05-29     2022        Final
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 947   335984       Delhi  2008-04-19  2007/08            3
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 949   335982   Bangalore  2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# ...

# %%
v3=(ds[ds["Team1"]=="Mumbai Indians"].count()>1)
v3
v4=ds[ds["Team2"]=="Mumbai Indians"].count()>1
v4
# Out:
# ID                  True
# City                True
# Date                True
# Season              True
# MatchNumber         True
# Team1               True
# Team2               True
# Venue               True
# TossWinner          True
# TossDecision        True
# SuperOver           True
# WinningTeam         True
# WonBy               True
# Margin              True
# method             False
# Player_of_Match     True
# Team1Players        True
# Team2Players        True
# Umpire1             True
# Umpire2             True
# dtype: bool

# %%
v=v3[v3["WinningTeam"]!="Mumbai Indians"]
v
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: True
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-129-4f6ac532634c> in <module>
# ...

# %%
v1=v["Player_of_Match"]
v1
# Out:
# 0          HH Pandya
# 1         JC Buttler
# 2         RM Patidar
# 3          DA Miller
# 4      Harpreet Brar
#            ...
# 945        DJ Hussey
# 946       MV Boucher
# 947      MF Maharoof
# 948       MEK Hussey
# 949      BB McCullum
# Name: Player_of_Match, Length: 819, dtype: object

# %%
v4
# Out:
# ID                  True
# City                True
# Date                True
# Season              True
# MatchNumber         True
# Team1               True
# Team2               True
# Venue               True
# TossWinner          True
# TossDecision        True
# SuperOver           True
# WinningTeam         True
# WonBy               True
# Margin              True
# method             False
# Player_of_Match     True
# Team1Players        True
# Team2Players        True
# Umpire1             True
# Umpire2             True
# dtype: bool

# %%
v3
# Out:
# ID                  True
# City                True
# Date                True
# Season              True
# MatchNumber         True
# Team1               True
# Team2               True
# Venue               True
# TossWinner          True
# TossDecision        True
# SuperOver           True
# WinningTeam         True
# WonBy               True
# Margin              True
# method             False
# Player_of_Match     True
# Team1Players        True
# Team2Players        True
# Umpire1             True
# Umpire2             True
# dtype: bool

# %%
ds[((ds["Team1"]=="Mumbai Indians")|(ds["Team2"]=="Mumbai Indians"))&(ds['WinningTeam']!='Mumbai Indians')].Player_of_Match.value_counts()
# Out:
# SK Raina            4
# KL Rahul            4
# SPD Smith           4
# JH Kallis           3
# KC Sangakkara       3
#                    ..
# Anuj Rawat          1
# AD Russell          1
# RD Gaikwad          1
# Mukesh Choudhary    1
# SS Iyer             1
# Name: Player_of_Match, Length: 68, dtype: int64

# %%
sum(ds.SuperOver=="Y")
# Out:
# 14

# %%
sum(ds["TossWinner"]==ds['WinningTeam'])/ds.TossWinner.count()
# Out:
# 0.5147368421052632

# %%
ds
# Out:
#           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  2022-05-29     2022        Final
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 947   335984       Delhi  2008-04-19  2007/08            3
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 949   335982   Bangalore  2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# ...

# %%
ds["Venue"]
# Out:
# 0                Narendra Modi Stadium, Ahmedabad
# 1                Narendra Modi Stadium, Ahmedabad
# 2                           Eden Gardens, Kolkata
# 3                           Eden Gardens, Kolkata
# 4                        Wankhede Stadium, Mumbai
#                           ...
# 945                                  Eden Gardens
# 946                              Wankhede Stadium
# 947                              Feroz Shah Kotla
# 948    Punjab Cricket Association Stadium, Mohali
# 949                         M Chinnaswamy Stadium
# Name: Venue, Length: 950, dtype: object

# %%
ds[(ds["WinningTeam"]=="Mumbai Indians")&(ds['Venue']=="Wankhede Stadium, Mumbai")]
# Out:
#          ID    City        Date Season MatchNumber                Team1  \
# 5   1304115  Mumbai  2022-05-21   2022          69       Delhi Capitals
# 15  1304105  Mumbai  2022-05-12   2022          59  Chennai Super Kings
#
#              Team2                     Venue      TossWinner TossDecision  \
# 5   Mumbai Indians  Wankhede Stadium, Mumbai  Mumbai Indians        field
# 15  Mumbai Indians  Wankhede Stadium, Mumbai  Mumbai Indians        field
#
#    SuperOver     WinningTeam    WonBy  Margin method Player_of_Match  \
# 5          N  Mumbai Indians  Wickets     5.0    NaN       JJ Bumrah
# 15         N  Mumbai Indians  Wickets     5.0    NaN         DR Sams
#
#                                          Team1Players  \
# 5   ['PP Shaw', 'DA Warner', 'MR Marsh', 'RR Pant'...
# 15  ['RD Gaikwad', 'DP Conway', 'MM Ali', 'RV Utha...
#
#                                          Team2Players                Umpire1  \
# ...
