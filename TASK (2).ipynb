# %%
import numpy as np
import pandas as pd
df=pd.read_csv("production_analysis_dataset.csv")
df.columns
# Out:
# Index(['production_id', 'product_category', 'factory', 'shift', 'supervisor',
#        'units_produced', 'defective_units', 'production_time_hr',
#        'machine_downtime_hr', 'energy_consumption_kwh', 'profit'],
#       dtype='object')

# %% [markdown]
# # Q1. Find the total units produced by each product_category.

# %%
df.groupby("product_category")[ 'units_produced'].sum()
# Out:
# product_category
# Automotive     9408
# Electronics    7491
# Furniture      7251
# Name: units_produced, dtype: int64

# %% [markdown]
# # Q2. Calculate the average profit for each factory.

# %%
df.groupby("factory")["profit"].mean()
# Out:
# factory
# Plant_A    18044.375000
# Plant_B    16973.384615
# Plant_C    18086.076923
# Name: profit, dtype: float64

# %% [markdown]
# # Q3. Find the total defective_units for each shift.

# %%
df.groupby("shift")['defective_units'].sum()
# Out:
# shift
# Evening    132
# Morning    472
# Night      471
# Name: defective_units, dtype: int64

# %% [markdown]
# # Q4. Calculate the average production_time_hr for each supervisor.

# %%
df.groupby('supervisor')['production_time_hr'].mean()
# Out:
# supervisor
# S1    7.801818
# S2    7.450000
# S3    7.882000
# S4    7.956154
# Name: production_time_hr, dtype: float64

# %% [markdown]
# # Q5. Find the total energy_consumption_kwh for each factory and shift.

# %%
df.groupby(['factory','shift'])['energy_consumption_kwh'].sum()
# Out:
# factory  shift
# Plant_A  Evening     3330
#          Morning    11144
#          Night      12913
# Plant_B  Evening     2889
#          Morning     7923
#          Night       4981
# Plant_C  Evening     2214
#          Morning     5632
#          Night       7363
# Name: energy_consumption_kwh, dtype: int64

# %% [markdown]
# # Q6. For each product_category, calculate:
# total units_produced
# average profit
# maximum defective_units.

# %%
# aggregation
df.groupby("product_category").agg({"units_produced":"sum","profit":"mean","defective_units":'max'})
# Out:
#                   units_produced        profit  defective_units
# product_category
# Automotive                  9408  18374.722222               34
# Electronics                 7491  16945.750000               40
# Furniture                   7251  17935.062500               39

# %% [markdown]
# # Q7. For each factory, calculate:
# mean production_time_hr
# median machine_downtime_hr.

# %%
df.groupby("factory").agg({"machine_downtime_hr":"median","production_time_hr":"mean"})
# Out:
#          machine_downtime_hr  production_time_hr
# factory
# Plant_A                0.945            7.890000
# Plant_B                1.070            7.579231
# Plant_C                0.850            7.810769

# %% [markdown]
# # Q8. For each shift, compute:
# minimum profit
# maximum profit
# average units_produced.

# %%
df.groupby("shift").agg({"profit":['min','max'],"units_produced":"max"})
# Out:
#         profit        units_produced
#            min    max            max
# shift
# Evening  10009  22302            690
# Morning  10722  24358            665
# Night    12045  24586            666

# %% [markdown]
# # Q9. For each supervisor, calculate:
# total units_produced
# total defective_units.

# %%
df.groupby("supervisor").agg({'units_produced':'sum',"defective_units":'sum'})
# Out:
#             units_produced  defective_units
# supervisor
# S1                    5231              209
# S2                    6069              264
# S3                    7418              273
# S4                    5432              329

# %% [markdown]
# # Q10. Using apply(), calculate the defect rate for each row:
# defect_rate=defective_units/units_produced

# %%
df.apply(lambda x: x['defective_units']/x['units_produced'],axis=1)
# Out:
# 0     0.019139
# 1     0.053156
# 2     0.058559
# 3     0.046414
# 4     0.044118
# 5     0.045089
# 6     0.082621
# 7     0.013657
# 8     0.063796
# 9     0.043564
# 10    0.067729
# 11    0.050167
# 12    0.039683
# 13    0.008576
# 14    0.071111
# 15    0.019678
# 16    0.021739
# 17    0.078431
# 18    0.104956
# 19    0.025818
# 20    0.036090
# 21    0.021687
# 22    0.021583
# 23    0.095355
# 24    0.027708
# 25    0.090634
# 26    0.086253
# 27    0.057637
# 28    0.096346
# 29    0.044855
# 30    0.024316
# 31    0.026866
# 32    0.016207
# 33    0.049763
# 34    0.017799
# 35    0.033708
# 36    0.017214
# 37    0.052392
# 38    0.018692
# 39    0.086387
# 40    0.081800
# 41    0.017161
# 42    0.079487
# 43    0.034404
# 44    0.050104
# 45    0.020362
# 46    0.038217
# 47    0.052521
# 48    0.048338
# 49    0.065844
# dtype: float64

# %% [markdown]
# # Q11. Using groupby().apply(), find the profit range (max − min) for each factory.

# %%
df.groupby("factory")["profit"].apply(lambda x:x.max()-x.min())
# Out:
# factory
# Plant_A    14199
# Plant_B    14349
# Plant_C    12745
# Name: profit, dtype: int64

# %% [markdown]
# # Q12. Using groupby().apply(), find the row with maximum units_produced in each product_category.

# %%
result=df.groupby('product_category',as_index=False).apply(lambda group: group[group['units_produced']==
                                                           group['units_produced'].max()]).reset_index()
result
# Out:
#    level_0  level_1  production_id product_category  factory    shift  \
# 0        0       16            117       Automotive  Plant_B  Evening
# 1        1        2            103      Electronics  Plant_A    Night
# 2        2       34            135        Furniture  Plant_A  Morning
#
#   supervisor  units_produced  defective_units  production_time_hr  \
# 0         S1             690               15                8.12
# 1         S4             666               39                7.76
# 2         S3             618               11                6.72
#
#    machine_downtime_hr  energy_consumption_kwh  profit
# 0                 1.21                    1343   10009
# 1                 0.78                    1084   23261
# 2                 0.48                    1071   12170

# %% [markdown]
# # Q13. Use apply() to create a new column efficiency_score:
# efficiency=units_produced/production_time_hr

# %%
df.apply(lambda x: x['units_produced']/x['production_time_hr'],axis=1)
# Out:
# 0      95.288754
# 1      91.212121
# 2      85.824742
# 3      68.005739
# 4      53.363229
# 5      75.455650
# 6      47.885402
# 7      79.111645
# 8      87.569832
# 9      75.373134
# 10     72.438672
# 11     78.787879
# 12     42.567568
# 13     68.266979
# 14     64.562410
# 15     61.361142
# 16     84.975369
# 17     39.059081
# 18     38.324022
# 19     79.589041
# 20     86.363636
# 21     55.259654
# 22     45.227766
# 23     59.275362
# 24     58.468336
# 25     38.133641
# 26     52.624113
# 27     49.571429
# 28     41.232877
# 29     51.285521
# 30     39.878788
# 31     39.273154
# 32     79.510309
# 33     54.876463
# 34     91.964286
# 35     56.978233
# 36     68.562232
# 37     52.827918
# 38     63.126844
# 39     46.813725
# 40     70.461095
# 41     84.788360
# 42     59.360731
# 43     49.209932
# 44     53.459821
# 45     47.021277
# 46     34.392114
# 47     60.947503
# 48    101.689708
# 49     72.429210
# dtype: float64

# %% [markdown]
# # Q14. Find how many times each product_category appears in the dataset.

# %%
df.product_category.value_counts()
# Out:
# Automotive     18
# Electronics    16
# Furniture      16
# Name: product_category, dtype: int64

# %% [markdown]
# # Q15. Count the number of records for each shift.

# %%
df['shift'].value_counts()
# Out:
# Morning    22
# Night      21
# Evening     7
# Name: shift, dtype: int64

# %% [markdown]
# # Q16. Find the most frequent supervisor using value_counts().

# %%
df.supervisor.value_counts().head(1)
# Out:
# S3    15
# Name: supervisor, dtype: int64

# %% [markdown]
# # Q17. Sort the dataset by profit in descending order.

# %%
df.sort_values('profit',ascending=True)
# Out:
#     production_id product_category  factory    shift supervisor  \
# 16            117       Automotive  Plant_B  Evening         S1
# 44            145       Automotive  Plant_A  Evening         S3
# 38            139      Electronics  Plant_B  Morning         S3
# 3             104      Electronics  Plant_B  Morning         S3
# 39            140      Electronics  Plant_C  Morning         S1
# 4             105        Furniture  Plant_A    Night         S3
# 34            135        Furniture  Plant_A  Morning         S3
# 0             101       Automotive  Plant_A    Night         S1
# 30            131      Electronics  Plant_C  Morning         S2
# 6             107        Furniture  Plant_B  Morning         S3
# 19            120       Automotive  Plant_C    Night         S2
# 17            118      Electronics  Plant_A    Night         S1
# 7             108      Electronics  Plant_B  Evening         S3
# 25            126      Electronics  Plant_A    Night         S4
# 46            147      Electronics  Plant_A    Night         S4
# 28            129        Furniture  Plant_C    Night         S4
# 32            133        Furniture  Plant_A    Night         S3
# 40            141      Electronics  Plant_B  Morning         S2
# 12            113        Furniture  Plant_C  Evening         S3
# 47            148       Automotive  Plant_A  Evening         S1
# 24            125        Furniture  Plant_C  Morning         S1
# 20            121       Automotive  Plant_B  Morning         S2
# 26            127       Automotive  Plant_A  Morning         S1
# 33            134        Furniture  Plant_A  Morning         S4
# 1             102       Automotive  Plant_A    Night         S2
# 15            116       Automotive  Plant_A  Morning         S3
# 45            146        Furniture  Plant_C    Night         S3
# 11            112        Furniture  Plant_A  Morning         S1
# 22            123      Electronics  Plant_B    Night         S4
# 10            111       Automotive  Plant_B    Night         S4
# 23            124        Furniture  Plant_A  Evening         S4
# 21            122      Electronics  Plant_A  Morning         S1
# 35            136       Automotive  Plant_C  Morning         S3
# 41            142       Automotive  Plant_A  Morning         S2
# 49            150        Furniture  Plant_C  Morning         S3
# 5             106      Electronics  Plant_B  Morning         S2
# 48            149       Automotive  Plant_C    Night         S2
# 37            138       Automotive  Plant_B    Night         S4
# 29            130       Automotive  Plant_A    Night         S3
# 13            114        Furniture  Plant_C  Evening         S1
# 18            119      Electronics  Plant_A    Night         S4
# 8             109      Electronics  Plant_A  Morning         S3
# 42            143        Furniture  Plant_C    Night         S2
# 2             103      Electronics  Plant_A    Night         S4
# 43            144        Furniture  Plant_A  Morning         S4
# 27            128        Furniture  Plant_A  Morning         S4
# 14            115       Automotive  Plant_B    Night         S2
# 9             110       Automotive  Plant_B  Morning         S4
# 36            137      Electronics  Plant_C    Night         S2
# 31            132       Automotive  Plant_A    Night         S1
#
#     units_produced  defective_units  production_time_hr  machine_downtime_hr  \
# 16             690               15                8.12                 1.21
# 44             479               24                8.96                 1.33
# 38             428                8                6.78                 0.75
# 3              474               22                6.97                 1.44
# 39             382               33                8.16                 0.76
# 4              476               21                8.92                 1.15
# 34             618               11                6.72                 0.48
# 0              627               12                6.58                 0.56
# 30             329                8                8.25                 0.85
# 6              351               29                7.33                 1.03
# 19             581               15                7.30                 1.33
# 17             357               28                9.14                 1.28
# 7              659                9                8.33                 0.42
# 25             331               30                8.68                 1.24
# 46             314               12                9.13                 0.54
# 28             301               29                7.30                 1.22
# 32             617               10                7.76                 0.96
# 40             489               40                6.94                 0.37
# 12             378               15                8.88                 0.75
# 47             476               25                7.81                 1.48
# 24             397               11                6.79                 0.76
# 20             665               24                7.70                 1.07
# 26             371               32                7.05                 0.80
# 33             422               21                7.69                 1.07
# 1              602               32                6.60                 0.32
# 15             559               11                9.11                 0.59
# 45             442                9                9.40                 0.56
# 11             598               30                7.59                 1.50
# 22             417                9                9.22                 1.32
# 10             502               34                6.93                 0.38
# 23             409               39                6.90                 1.42
# 21             415                9                7.51                 0.96
# 35             445               15                7.81                 0.91
# 41             641               11                7.56                 0.93
# 49             486               32                6.71                 1.06
# 5              621               28                8.23                 1.12
# 48             662               32                6.51                 1.40
# 37             439               23                8.31                 1.13
# 29             379               17                7.39                 1.46
# 13             583                5                8.54                 0.35
# 18             343               36                8.95                 1.47
# 8              627               40                7.16                 0.62
# 42             390               31                6.57                 1.16
# 2              666               39                7.76                 0.78
# 43             436               15                8.86                 0.34
# 27             347               20                7.00                 0.83
# 14             450               32                6.97                 0.20
# 9              505               22                6.70                 1.39
# 36             639               11                9.32                 0.37
# 31             335                9                8.53                 0.51
#
#     energy_consumption_kwh  profit
# 16                    1343   10009
# 44                    1028   10387
# 38                    1083   10722
# 3                     1144   11674
# 39                     809   11832
# 4                     1349   12045
# 34                    1071   12170
# 0                     1028   12286
# 30                    1343   12579
# 6                     1173   12664
# 19                    1233   13470
# 17                    1114   13923
# 7                     1546   14010
# 25                     911   14073
# 46                    1394   14349
# 28                    1265   14673
# 32                    1335   15183
# 40                    1115   15974
# 12                     865   16304
# 47                     918   16311
# 24                    1233   16735
# 20                    1182   17177
# 26                     877   17260
# 33                    1107   17491
# 1                     1038   18279
# 15                    1454   18317
# 45                    1456   18346
# 11                     941   18348
# 22                     872   18423
# 10                    1562   19197
# 23                    1384   19440
# 21                    1035   19641
# 35                    1109   20021
# 41                    1216   20168
# 49                    1138   20209
# 5                      846   20834
# 48                    1351   21253
# 37                    1008   21263
# 29                    1393   22054
# 13                    1349   22302
# 18                    1345   22547
# 8                     1586   22713
# 42                    1140   22818
# 2                     1084   23261
# 43                     839   24067
# 27                    1018   24166
# 14                    1539   24349
# 9                     1380   24358
# 36                     918   24577
# 31                     922   24586

# %% [markdown]
# # Q18. Sort the dataset by:
# •	product_category ascending
# •	units_produced descending

# %%
df.sort_values(['product_category','units_produced'],ascending=[True,False])
# Out:
#     production_id product_category  factory    shift supervisor  \
# 16            117       Automotive  Plant_B  Evening         S1
# 20            121       Automotive  Plant_B  Morning         S2
# 48            149       Automotive  Plant_C    Night         S2
# 41            142       Automotive  Plant_A  Morning         S2
# 0             101       Automotive  Plant_A    Night         S1
# 1             102       Automotive  Plant_A    Night         S2
# 19            120       Automotive  Plant_C    Night         S2
# 15            116       Automotive  Plant_A  Morning         S3
# 9             110       Automotive  Plant_B  Morning         S4
# 10            111       Automotive  Plant_B    Night         S4
# 44            145       Automotive  Plant_A  Evening         S3
# 47            148       Automotive  Plant_A  Evening         S1
# 14            115       Automotive  Plant_B    Night         S2
# 35            136       Automotive  Plant_C  Morning         S3
# 37            138       Automotive  Plant_B    Night         S4
# 29            130       Automotive  Plant_A    Night         S3
# 26            127       Automotive  Plant_A  Morning         S1
# 31            132       Automotive  Plant_A    Night         S1
# 2             103      Electronics  Plant_A    Night         S4
# 7             108      Electronics  Plant_B  Evening         S3
# 36            137      Electronics  Plant_C    Night         S2
# 8             109      Electronics  Plant_A  Morning         S3
# 5             106      Electronics  Plant_B  Morning         S2
# 40            141      Electronics  Plant_B  Morning         S2
# 3             104      Electronics  Plant_B  Morning         S3
# 38            139      Electronics  Plant_B  Morning         S3
# 22            123      Electronics  Plant_B    Night         S4
# 21            122      Electronics  Plant_A  Morning         S1
# 39            140      Electronics  Plant_C  Morning         S1
# 17            118      Electronics  Plant_A    Night         S1
# 18            119      Electronics  Plant_A    Night         S4
# 25            126      Electronics  Plant_A    Night         S4
# 30            131      Electronics  Plant_C  Morning         S2
# 46            147      Electronics  Plant_A    Night         S4
# 34            135        Furniture  Plant_A  Morning         S3
# 32            133        Furniture  Plant_A    Night         S3
# 11            112        Furniture  Plant_A  Morning         S1
# 13            114        Furniture  Plant_C  Evening         S1
# 49            150        Furniture  Plant_C  Morning         S3
# 4             105        Furniture  Plant_A    Night         S3
# 45            146        Furniture  Plant_C    Night         S3
# 43            144        Furniture  Plant_A  Morning         S4
# 33            134        Furniture  Plant_A  Morning         S4
# 23            124        Furniture  Plant_A  Evening         S4
# 24            125        Furniture  Plant_C  Morning         S1
# 42            143        Furniture  Plant_C    Night         S2
# 12            113        Furniture  Plant_C  Evening         S3
# 6             107        Furniture  Plant_B  Morning         S3
# 27            128        Furniture  Plant_A  Morning         S4
# 28            129        Furniture  Plant_C    Night         S4
#
#     units_produced  defective_units  production_time_hr  machine_downtime_hr  \
# 16             690               15                8.12                 1.21
# 20             665               24                7.70                 1.07
# 48             662               32                6.51                 1.40
# 41             641               11                7.56                 0.93
# 0              627               12                6.58                 0.56
# 1              602               32                6.60                 0.32
# 19             581               15                7.30                 1.33
# 15             559               11                9.11                 0.59
# 9              505               22                6.70                 1.39
# 10             502               34                6.93                 0.38
# 44             479               24                8.96                 1.33
# 47             476               25                7.81                 1.48
# 14             450               32                6.97                 0.20
# 35             445               15                7.81                 0.91
# 37             439               23                8.31                 1.13
# 29             379               17                7.39                 1.46
# 26             371               32                7.05                 0.80
# 31             335                9                8.53                 0.51
# 2              666               39                7.76                 0.78
# 7              659                9                8.33                 0.42
# 36             639               11                9.32                 0.37
# 8              627               40                7.16                 0.62
# 5              621               28                8.23                 1.12
# 40             489               40                6.94                 0.37
# 3              474               22                6.97                 1.44
# 38             428                8                6.78                 0.75
# 22             417                9                9.22                 1.32
# 21             415                9                7.51                 0.96
# 39             382               33                8.16                 0.76
# 17             357               28                9.14                 1.28
# 18             343               36                8.95                 1.47
# 25             331               30                8.68                 1.24
# 30             329                8                8.25                 0.85
# 46             314               12                9.13                 0.54
# 34             618               11                6.72                 0.48
# 32             617               10                7.76                 0.96
# 11             598               30                7.59                 1.50
# 13             583                5                8.54                 0.35
# 49             486               32                6.71                 1.06
# 4              476               21                8.92                 1.15
# 45             442                9                9.40                 0.56
# 43             436               15                8.86                 0.34
# 33             422               21                7.69                 1.07
# 23             409               39                6.90                 1.42
# 24             397               11                6.79                 0.76
# 42             390               31                6.57                 1.16
# 12             378               15                8.88                 0.75
# 6              351               29                7.33                 1.03
# 27             347               20                7.00                 0.83
# 28             301               29                7.30                 1.22
#
#     energy_consumption_kwh  profit
# 16                    1343   10009
# 20                    1182   17177
# 48                    1351   21253
# 41                    1216   20168
# 0                     1028   12286
# 1                     1038   18279
# 19                    1233   13470
# 15                    1454   18317
# 9                     1380   24358
# 10                    1562   19197
# 44                    1028   10387
# 47                     918   16311
# 14                    1539   24349
# 35                    1109   20021
# 37                    1008   21263
# 29                    1393   22054
# 26                     877   17260
# 31                     922   24586
# 2                     1084   23261
# 7                     1546   14010
# 36                     918   24577
# 8                     1586   22713
# 5                      846   20834
# 40                    1115   15974
# 3                     1144   11674
# 38                    1083   10722
# 22                     872   18423
# 21                    1035   19641
# 39                     809   11832
# 17                    1114   13923
# 18                    1345   22547
# 25                     911   14073
# 30                    1343   12579
# 46                    1394   14349
# 34                    1071   12170
# 32                    1335   15183
# 11                     941   18348
# 13                    1349   22302
# 49                    1138   20209
# 4                     1349   12045
# 45                    1456   18346
# 43                     839   24067
# 33                    1107   17491
# 23                    1384   19440
# 24                    1233   16735
# 42                    1140   22818
# 12                     865   16304
# 6                     1173   12664
# 27                    1018   24166
# 28                    1265   14673

# %%
df=pd.read_csv('IPL_Matches_2008_2022.csv')

# %%
df
# Out:
#           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  2022-05-29     2022        Final
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 947   335984       Delhi  2008-04-19  2007/08            3
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 949   335982   Bangalore  2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# 3               Rajasthan Royals               Gujarat Titans
# 4            Sunrisers Hyderabad                 Punjab Kings
# ..                           ...                          ...
# 945        Kolkata Knight Riders              Deccan Chargers
# 946               Mumbai Indians  Royal Challengers Bangalore
# 947             Delhi Daredevils             Rajasthan Royals
# 948              Kings XI Punjab          Chennai Super Kings
# 949  Royal Challengers Bangalore        Kolkata Knight Riders
#
#                                           Venue                   TossWinner  \
# 0              Narendra Modi Stadium, Ahmedabad             Rajasthan Royals
# 1              Narendra Modi Stadium, Ahmedabad             Rajasthan Royals
# 2                         Eden Gardens, Kolkata         Lucknow Super Giants
# 3                         Eden Gardens, Kolkata               Gujarat Titans
# 4                      Wankhede Stadium, Mumbai          Sunrisers Hyderabad
# ..                                          ...                          ...
# 945                                Eden Gardens              Deccan Chargers
# 946                            Wankhede Stadium               Mumbai Indians
# 947                            Feroz Shah Kotla             Rajasthan Royals
# 948  Punjab Cricket Association Stadium, Mohali          Chennai Super Kings
# 949                       M Chinnaswamy Stadium  Royal Challengers Bangalore
#
#     TossDecision SuperOver                  WinningTeam    WonBy  Margin  \
# 0            bat         N               Gujarat Titans  Wickets     7.0
# 1          field         N             Rajasthan Royals  Wickets     7.0
# 2          field         N  Royal Challengers Bangalore     Runs    14.0
# 3          field         N               Gujarat Titans  Wickets     7.0
# 4            bat         N                 Punjab Kings  Wickets     5.0
# ..           ...       ...                          ...      ...     ...
# 945          bat         N        Kolkata Knight Riders  Wickets     5.0
# 946          bat         N  Royal Challengers Bangalore  Wickets     5.0
# 947          bat         N             Delhi Daredevils  Wickets     9.0
# 948          bat         N          Chennai Super Kings     Runs    33.0
# 949        field         N        Kolkata Knight Riders     Runs   140.0
#
#     method Player_of_Match                                       Team1Players  \
# 0      NaN       HH Pandya  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
# 1      NaN      JC Buttler  ['V Kohli', 'F du Plessis', 'RM Patidar', 'GJ ...
# 2      NaN      RM Patidar  ['V Kohli', 'F du Plessis', 'RM Patidar', 'GJ ...
# 3      NaN       DA Miller  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
# 4      NaN   Harpreet Brar  ['PK Garg', 'Abhishek Sharma', 'RA Tripathi', ...
# ..     ...             ...                                                ...
# 945    NaN       DJ Hussey  ['WP Saha', 'BB McCullum', 'RT Ponting', 'SC G...
# 946    NaN      MV Boucher  ['L Ronchi', 'ST Jayasuriya', 'DJ Thornely', '...
# 947    NaN     MF Maharoof  ['G Gambhir', 'V Sehwag', 'S Dhawan', 'MK Tiwa...
# 948    NaN      MEK Hussey  ['K Goel', 'JR Hopes', 'KC Sangakkara', 'Yuvra...
# 949    NaN     BB McCullum  ['R Dravid', 'W Jaffer', 'V Kohli', 'JH Kallis...
#
#                                           Team2Players        Umpire1  \
# 0    ['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pan...    CB Gaffaney
# 1    ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...    CB Gaffaney
# 2    ['Q de Kock', 'KL Rahul', 'M Vohra', 'DJ Hooda...  J Madanagopal
# 3    ['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pan...   BNJ Oxenford
# 4    ['JM Bairstow', 'S Dhawan', 'M Shahrukh Khan',...   AK Chaudhary
# ..                                                 ...            ...
# 945  ['AC Gilchrist', 'Y Venugopal Rao', 'VVS Laxma...      BF Bowden
# 946  ['S Chanderpaul', 'R Dravid', 'LRPL Taylor', '...       SJ Davis
# 947  ['T Kohli', 'YK Pathan', 'SR Watson', 'M Kaif'...      Aleem Dar
# 948  ['PA Patel', 'ML Hayden', 'MEK Hussey', 'MS Dh...      MR Benson
# 949  ['SC Ganguly', 'BB McCullum', 'RT Ponting', 'D...      Asad Rauf
#
#             Umpire2
# 0       Nitin Menon
# 1       Nitin Menon
# 2          MA Gough
# 3         VK Sharma
# 4     NA Patwardhan
# ..              ...
# 945     K Hariharan
# 946       DJ Harper
# 947  GA Pratapkumar
# 948      SL Shastri
# 949     RE Koertzen
#
# [950 rows x 20 columns]

# %%
# season wise most winning team with count

df.groupby("Season")['WinningTeam'].apply(lambda x:x.value_counts().head(1))
# Out:
# Season
# 2007/08  Rajasthan Royals         13
# 2009     Delhi Daredevils         10
# 2009/10  Mumbai Indians           11
# 2011     Chennai Super Kings      11
# 2012     Kolkata Knight Riders    12
# 2013     Mumbai Indians           13
# 2014     Kings XI Punjab          12
# 2015     Chennai Super Kings      10
# 2016     Sunrisers Hyderabad      11
# 2017     Mumbai Indians           12
# 2018     Chennai Super Kings      11
# 2019     Mumbai Indians           11
# 2020/21  Mumbai Indians           11
# 2021     Chennai Super Kings      11
# 2022     Gujarat Titans           12
# Name: WinningTeam, dtype: int64

# %%
# teamwise man of the match-> no of player
df.groupby("WinningTeam")['Player_of_Match'].nunique()
# Out:
# WinningTeam
# Chennai Super Kings            39
# Deccan Chargers                19
# Delhi Capitals                 16
# Delhi Daredevils               39
# Gujarat Lions                   7
# Gujarat Titans                  9
# Kings XI Punjab                42
# Kochi Tuskers Kerala            4
# Kolkata Knight Riders          44
# Lucknow Super Giants            6
# Mumbai Indians                 43
# Pune Warriors                  11
# Punjab Kings                   10
# Rajasthan Royals               41
# Rising Pune Supergiant          7
# Rising Pune Supergiants         3
# Royal Challengers Bangalore    36
# Sunrisers Hyderabad            36
# Name: Player_of_Match, dtype: int64

# %%
# 5 venue->where most m,atched being played
# team->which team dominate

new=pd.DataFrame()
new['count']=df.Venue.value_counts().head()

# %%
new=new.reset_index()
new
# Out:
#                                        index  count
# 0                               Eden Gardens     77
# 1                           Wankhede Stadium     73
# 2                      M Chinnaswamy Stadium     65
# 3                           Feroz Shah Kotla     60
# 4  Rajiv Gandhi International Stadium, Uppal     49

# %%
df1=new.merge(df,on="Venue",how="inner")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-60-eacbd68feca8> in <module>
# ----> 1 df1=new.merge(df,on="Venue",how="inner")
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#    7944         from pandas.core.reshape.merge import merge
#    7945
# -> 7946         return merge(
#    7947             self,
#    7948             right,
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      72     validate=None,
#      73 ) -> "DataFrame":
# ---> 74     op = _MergeOperation(
#      75         left,
#      76         right,
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     650             self.right_join_keys,
#     651             self.join_names,
# --> 652         ) = self._get_merge_keys()
#     653
#     654         # validate the merge keys dtypes. We may need to coerce
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in _get_merge_keys(self)
#    1016                         right_keys.append(rk)
#    1017                     if lk is not None:
# -> 1018                         left_keys.append(left._get_label_or_level_values(lk))
#    1019                         join_names.append(lk)
#    1020                     else:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in _get_label_or_level_values(self, key, axis)
#    1561             values = self.axes[axis].get_level_values(key)._values
#    1562         else:
# -> 1563             raise KeyError(key)
#    1564
#    1565         # Check for duplicates
#
# KeyError: 'Venue'

# %%
df1.groupby("Venue")['WinningTeam'].apply(lambda x: x.value_counts().head(1))
